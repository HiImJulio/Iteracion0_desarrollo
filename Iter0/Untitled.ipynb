# %%
import numpy as np
from numpy import random

# %%
class Persona:
        def __init__(self, idpersona,edad,lugar):           
            self.idpersona=idpersona
            self.edad=edad
            self.estadosposibles=["sano","incubando","incubandoContagioso","sintomatico","asintomatico","muerto","inmune"]
            self.estado=self.estadosposibles[0]
            self.lugar=lugar
            self.diasestado=0
            self.cambioEstado=np.inf
            self.contadorInfecciones=0
            
            
           
        def __str__(self):
            #Devuelve un string con la información útil del sujeto
            return str(self.idpersona) + "," + str(self.estado) + "," + str(self.lugar)           

        def puede_propagar(self):
            return ((self.estado == "sintomatico") or (self.estado == "asintomatico") or (self.estado == "incubandoContagioso"))
        def susceptible(self):
            return (self.estado == "sano")
        
        def infectar(self,posibilidadContagio,ciudad,mediaincubacion,desvincubacion): #media y desv covid: 7.5 y 3.5
            if self.puede_propagar():
                for i in range(len(ciudad[self.lugar])): 
                    if (ciudad[self.lugar][i].susceptible):
                        nocontagia=random.uniform(0, 1)   #Numero al azar, si es menor que la pos. de contagio, contagiará
                        if (nocontagia <posibilidadContagio/24):
                            ciudad[self.lugar][i].estado=ciudad[self.lugar][i].estadosposibles[1]
                            ciudad[self.lugar][i].diasestado=0
                            ciudad[self.lugar][i].cambioEstado=random.randint(int(mediaincubacion-desvincubacion),int(mediaincubacion+desvincubacion))
                            self.contadorInfecciones +=1

# %%
def crearciudadv0(numpersonas,personasedificio):
    edificios = []
    capacidadusada=0
    edificioactual=0
    while (capacidadusada < numpersonas):
        column = []
        esteedificio=random.randint(1,personasedificio*3) #si usamos desviación tipica de capacidad de edificio, iria aqui
        contadoredificio=0 #numero de personas colocadas en este edificio
        print(f"edificio actual:{edificioactual}")
        
        while (capacidadusada < numpersonas) and (contadoredificio < esteedificio):
            
            print(f"contador del edificio:{contadoredificio}")
            print(f"capacidad:{esteedificio}")
            
            column.append(Persona(capacidadusada,20,edificioactual))
            capacidadusada+=1
            contadoredificio+=1
            
            
        edificios.append(column)
        edificioactual+=1
        
    return edificios
def printearciudad(ciudad):        
    for j in range(len(ciudad)):
        for i in range(len(ciudad[j])):
            print(ciudad[j][i])
        print()

# %%
ciudad=crearciudadv0(200,15)
# Out:
# edificio actual:0
# contador del edificio:0
# capacidad:17
# contador del edificio:1
# capacidad:17
# contador del edificio:2
# capacidad:17
# contador del edificio:3
# capacidad:17
# contador del edificio:4
# capacidad:17
# contador del edificio:5
# capacidad:17
# contador del edificio:6
# capacidad:17
# contador del edificio:7
# capacidad:17
# contador del edificio:8
# capacidad:17
# contador del edificio:9
# capacidad:17
# contador del edificio:10
# capacidad:17
# contador del edificio:11
# capacidad:17
# contador del edificio:12
# capacidad:17
# contador del edificio:13
# capacidad:17
# contador del edificio:14
# capacidad:17
# contador del edificio:15
# capacidad:17
# contador del edificio:16
# capacidad:17
# edificio actual:1
# contador del edificio:0
# capacidad:11
# contador del edificio:1
# capacidad:11
# contador del edificio:2
# capacidad:11
# contador del edificio:3
# capacidad:11
# contador del edificio:4
# capacidad:11
# contador del edificio:5
# capacidad:11
# contador del edificio:6
# capacidad:11
# contador del edificio:7
# capacidad:11
# contador del edificio:8
# capacidad:11
# contador del edificio:9
# capacidad:11
# contador del edificio:10
# capacidad:11
# edificio actual:2
# contador del edificio:0
# capacidad:1
# edificio actual:3
# contador del edificio:0
# capacidad:41
# contador del edificio:1
# capacidad:41
# contador del edificio:2
# capacidad:41
# contador del edificio:3
# capacidad:41
# contador del edificio:4
# capacidad:41
# contador del edificio:5
# capacidad:41
# contador del edificio:6
# capacidad:41
# contador del edificio:7
# capacidad:41
# contador del edificio:8
# capacidad:41
# contador del edificio:9
# capacidad:41
# contador del edificio:10
# capacidad:41
# contador del edificio:11
# capacidad:41
# contador del edificio:12
# capacidad:41
# contador del edificio:13
# capacidad:41
# contador del edificio:14
# capacidad:41
# contador del edificio:15
# capacidad:41
# contador del edificio:16
# capacidad:41
# contador del edificio:17
# capacidad:41
# contador del edificio:18
# capacidad:41
# contador del edificio:19
# capacidad:41
# contador del edificio:20
# capacidad:41
# contador del edificio:21
# capacidad:41
# contador del edificio:22
# capacidad:41
# contador del edificio:23
# capacidad:41
# contador del edificio:24
# capacidad:41
# contador del edificio:25
# capacidad:41
# contador del edificio:26
# capacidad:41
# contador del edificio:27
# capacidad:41
# contador del edificio:28
# capacidad:41
# contador del edificio:29
# capacidad:41
# contador del edificio:30
# capacidad:41
# contador del edificio:31
# capacidad:41
# contador del edificio:32
# capacidad:41
# contador del edificio:33
# capacidad:41
# contador del edificio:34
# capacidad:41
# contador del edificio:35
# capacidad:41
# contador del edificio:36
# capacidad:41
# contador del edificio:37
# capacidad:41
# contador del edificio:38
# capacidad:41
# contador del edificio:39
# capacidad:41
# contador del edificio:40
# capacidad:41
# edificio actual:4
# contador del edificio:0
# capacidad:16
# contador del edificio:1
# capacidad:16
# contador del edificio:2
# capacidad:16
# contador del edificio:3
# capacidad:16
# contador del edificio:4
# capacidad:16
# contador del edificio:5
# capacidad:16
# contador del edificio:6
# capacidad:16
# contador del edificio:7
# capacidad:16
# contador del edificio:8
# capacidad:16
# contador del edificio:9
# capacidad:16
# contador del edificio:10
# capacidad:16
# contador del edificio:11
# capacidad:16
# contador del edificio:12
# capacidad:16
# contador del edificio:13
# capacidad:16
# contador del edificio:14
# capacidad:16
# contador del edificio:15
# capacidad:16
# edificio actual:5
# contador del edificio:0
# capacidad:31
# contador del edificio:1
# capacidad:31
# contador del edificio:2
# capacidad:31
# contador del edificio:3
# capacidad:31
# contador del edificio:4
# capacidad:31
# contador del edificio:5
# capacidad:31
# contador del edificio:6
# capacidad:31
# contador del edificio:7
# capacidad:31
# contador del edificio:8
# capacidad:31
# contador del edificio:9
# capacidad:31
# contador del edificio:10
# capacidad:31
# contador del edificio:11
# capacidad:31
# contador del edificio:12
# capacidad:31
# contador del edificio:13
# capacidad:31
# contador del edificio:14
# capacidad:31
# contador del edificio:15
# capacidad:31
# contador del edificio:16
# capacidad:31
# contador del edificio:17
# capacidad:31
# contador del edificio:18
# capacidad:31
# contador del edificio:19
# capacidad:31
# contador del edificio:20
# capacidad:31
# contador del edificio:21
# capacidad:31
# contador del edificio:22
# capacidad:31
# contador del edificio:23
# capacidad:31
# contador del edificio:24
# capacidad:31
# contador del edificio:25
# capacidad:31
# contador del edificio:26
# capacidad:31
# contador del edificio:27
# capacidad:31
# contador del edificio:28
# capacidad:31
# contador del edificio:29
# capacidad:31
# contador del edificio:30
# capacidad:31
# edificio actual:6
# contador del edificio:0
# capacidad:22
# contador del edificio:1
# capacidad:22
# contador del edificio:2
# capacidad:22
# contador del edificio:3
# capacidad:22
# contador del edificio:4
# capacidad:22
# contador del edificio:5
# capacidad:22
# contador del edificio:6
# capacidad:22
# contador del edificio:7
# capacidad:22
# contador del edificio:8
# capacidad:22
# contador del edificio:9
# capacidad:22
# contador del edificio:10
# capacidad:22
# contador del edificio:11
# capacidad:22
# contador del edificio:12
# capacidad:22
# contador del edificio:13
# capacidad:22
# contador del edificio:14
# capacidad:22
# contador del edificio:15
# capacidad:22
# contador del edificio:16
# capacidad:22
# contador del edificio:17
# capacidad:22
# contador del edificio:18
# capacidad:22
# contador del edificio:19
# capacidad:22
# contador del edificio:20
# capacidad:22
# contador del edificio:21
# capacidad:22
# edificio actual:7
# contador del edificio:0
# capacidad:26
# contador del edificio:1
# capacidad:26
# contador del edificio:2
# capacidad:26
# contador del edificio:3
# capacidad:26
# contador del edificio:4
# capacidad:26
# contador del edificio:5
# capacidad:26
# contador del edificio:6
# capacidad:26
# contador del edificio:7
# capacidad:26
# contador del edificio:8
# capacidad:26
# contador del edificio:9
# capacidad:26
# contador del edificio:10
# capacidad:26
# contador del edificio:11
# capacidad:26
# contador del edificio:12
# capacidad:26
# contador del edificio:13
# capacidad:26
# contador del edificio:14
# capacidad:26
# contador del edificio:15
# capacidad:26
# contador del edificio:16
# capacidad:26
# contador del edificio:17
# capacidad:26
# contador del edificio:18
# capacidad:26
# contador del edificio:19
# capacidad:26
# contador del edificio:20
# capacidad:26
# contador del edificio:21
# capacidad:26
# contador del edificio:22
# capacidad:26
# contador del edificio:23
# capacidad:26
# contador del edificio:24
# capacidad:26
# contador del edificio:25
# capacidad:26
# edificio actual:8
# contador del edificio:0
# capacidad:35
# contador del edificio:1
# capacidad:35
# contador del edificio:2
# capacidad:35
# contador del edificio:3
# capacidad:35
# contador del edificio:4
# capacidad:35
# contador del edificio:5
# capacidad:35
# contador del edificio:6
# capacidad:35
# contador del edificio:7
# capacidad:35
# contador del edificio:8
# capacidad:35
# contador del edificio:9
# capacidad:35
# contador del edificio:10
# capacidad:35
# contador del edificio:11
# capacidad:35
# contador del edificio:12
# capacidad:35
# contador del edificio:13
# capacidad:35
# contador del edificio:14
# capacidad:35
# contador del edificio:15
# capacidad:35
# contador del edificio:16
# capacidad:35
# contador del edificio:17
# capacidad:35
# contador del edificio:18
# capacidad:35
# contador del edificio:19
# capacidad:35
# contador del edificio:20
# capacidad:35
# contador del edificio:21
# capacidad:35
# contador del edificio:22
# capacidad:35
# contador del edificio:23
# capacidad:35
# contador del edificio:24
# capacidad:35
# contador del edificio:25
# capacidad:35
# contador del edificio:26
# capacidad:35
# contador del edificio:27
# capacidad:35
# contador del edificio:28
# capacidad:35
# contador del edificio:29
# capacidad:35
# contador del edificio:30
# capacidad:35
# contador del edificio:31
# capacidad:35
# contador del edificio:32
# capacidad:35
# contador del edificio:33
# capacidad:35
# contador del edificio:34
# capacidad:35

# %%
printearciudad(ciudad)
# Out:
# 0,sano,0
# 1,sano,0
# 2,sano,0
# 3,sano,0
# 4,sano,0
# 5,sano,0
# 6,sano,0
# 7,sano,0
# 8,sano,0
# 9,sano,0
# 10,sano,0
# 11,sano,0
# 12,sano,0
# 13,sano,0
# 14,sano,0
# 15,sano,0
# 16,sano,0
#
# 17,sano,1
# 18,sano,1
# 19,sano,1
# 20,sano,1
# 21,sano,1
# 22,sano,1
# 23,sano,1
# 24,sano,1
# 25,sano,1
# 26,sano,1
# 27,sano,1
#
# 28,sano,2
#
# 29,sano,3
# 30,sano,3
# 31,sano,3
# 32,sano,3
# 33,sano,3
# 34,sano,3
# 35,sano,3
# 36,sano,3
# 37,sano,3
# 38,sano,3
# 39,sano,3
# 40,sano,3
# 41,sano,3
# 42,sano,3
# 43,sano,3
# 44,sano,3
# 45,sano,3
# 46,sano,3
# 47,sano,3
# 48,sano,3
# 49,sano,3
# 50,sano,3
# 51,sano,3
# 52,sano,3
# 53,sano,3
# 54,sano,3
# 55,sano,3
# 56,sano,3
# 57,sano,3
# 58,sano,3
# 59,sano,3
# 60,sano,3
# 61,sano,3
# 62,sano,3
# 63,sano,3
# 64,sano,3
# 65,sano,3
# 66,sano,3
# 67,sano,3
# 68,sano,3
# 69,sano,3
#
# 70,sano,4
# 71,sano,4
# 72,sano,4
# 73,sano,4
# 74,sano,4
# 75,sano,4
# 76,sano,4
# 77,sano,4
# 78,sano,4
# 79,sano,4
# 80,sano,4
# 81,sano,4
# 82,sano,4
# 83,sano,4
# 84,sano,4
# 85,sano,4
#
# 86,sano,5
# 87,sano,5
# 88,sano,5
# 89,sano,5
# 90,sano,5
# 91,sano,5
# 92,sano,5
# 93,sano,5
# 94,sano,5
# 95,sano,5
# 96,sano,5
# 97,sano,5
# 98,sano,5
# 99,sano,5
# 100,sano,5
# 101,sano,5
# 102,sano,5
# 103,sano,5
# 104,sano,5
# 105,sano,5
# 106,sano,5
# 107,sano,5
# 108,sano,5
# 109,sano,5
# 110,sano,5
# 111,sano,5
# 112,sano,5
# 113,sano,5
# 114,sano,5
# 115,sano,5
# 116,sano,5
#
# 117,sano,6
# 118,sano,6
# 119,sano,6
# 120,sano,6
# 121,sano,6
# 122,sano,6
# 123,sano,6
# 124,sano,6
# 125,sano,6
# 126,sano,6
# 127,sano,6
# 128,sano,6
# 129,sano,6
# 130,sano,6
# 131,sano,6
# 132,sano,6
# 133,sano,6
# 134,sano,6
# 135,sano,6
# 136,sano,6
# 137,sano,6
# 138,sano,6
#
# 139,sano,7
# 140,sano,7
# 141,sano,7
# 142,sano,7
# 143,sano,7
# 144,sano,7
# 145,sano,7
# 146,sano,7
# 147,sano,7
# 148,sano,7
# 149,sano,7
# 150,sano,7
# 151,sano,7
# 152,sano,7
# 153,sano,7
# 154,sano,7
# 155,sano,7
# 156,sano,7
# 157,sano,7
# 158,sano,7
# 159,sano,7
# 160,sano,7
# 161,sano,7
# 162,sano,7
# 163,sano,7
# 164,sano,7
#
# 165,sano,8
# 166,sano,8
# 167,sano,8
# 168,sano,8
# 169,sano,8
# 170,sano,8
# 171,sano,8
# 172,sano,8
# 173,sano,8
# 174,sano,8
# 175,sano,8
# 176,sano,8
# 177,sano,8
# 178,sano,8
# 179,sano,8
# 180,sano,8
# 181,sano,8
# 182,sano,8
# 183,sano,8
# 184,sano,8
# 185,sano,8
# 186,sano,8
# 187,sano,8
# 188,sano,8
# 189,sano,8
# 190,sano,8
# 191,sano,8
# 192,sano,8
# 193,sano,8
# 194,sano,8
# 195,sano,8
# 196,sano,8
# 197,sano,8
# 198,sano,8
# 199,sano,8

# %%
ciudad[0][0].estado=ciudad[0][0].estadosposibles[3]
ciudad[0][0].infectar(0.8,ciudad,7.5,3.5)

# %%
 for i in range(len(ciudad[0])):
        print(ciudad[0][i])
# Out:
# 0,sintomatico,0
# 1,sano,0
# 2,incubando,0
# 3,sano,0
# 4,sano,0
# 5,sano,0
# 6,incubando,0
# 7,sano,0
# 8,sano,0
# 9,sano,0
# 10,sano,0
# 11,incubando,0
# 12,sano,0
# 13,sano,0
# 14,sano,0
# 15,sano,0
# 16,sano,0

# %%
print(0.8/24)
# Out:
# 0.03333333333333333
